# %%
# Import necessary packages
import dlib
import cv2
import time

# Function to convert and trim bounding box
def convert_and_trim_bb(image, rect):
    # Extract the starting and ending (x, y)-coordinates of the bounding box
    startX = rect.left()
    startY = rect.top()
    endX = rect.right()
    endY = rect.bottom()
    # Ensure the bounding box coordinates fall within the spatial dimensions of the image
    startX = max(0, startX)
    startY = max(0, startY)
    endX = min(endX, image.shape[1])
    endY = min(endY, image.shape[0])
    # Compute the width and height of the bounding box
    w = endX - startX
    h = endY - startY
    # Return the bounding box coordinates
    return (startX, startY, w, h)

# Load dlib's HOG + Linear SVM face detector
print("[INFO] Loading HOG + Linear SVM face detector...")
detector = dlib.get_frontal_face_detector()

# Open webcam for live video
cap = cv2.VideoCapture(0)  # Default camera (ID = 0)
if not cap.isOpened():
    print("[ERROR] Could not open webcam.")
    exit()

print("[INFO] Starting live face detection. Press 'q' to quit.")

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        print("[ERROR] Failed to grab frame.")
        break

    # Resize the frame to a width of 600 pixels
    frame = cv2.resize(frame, (600, int(frame.shape[0] * (600 / frame.shape[1]))))

    # Convert BGR to RGB (as dlib expects RGB images)
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Perform face detection using dlib's face detector
    start = time.time()
    rects = detector(rgb, 1)  # `1` is the upsample parameter
    end = time.time()

    print("[INFO] Face detection took {:.4f} seconds".format(end - start))

    # Convert dlib rectangles to bounding boxes
    boxes = [convert_and_trim_bb(frame, r) for r in rects]

    # Draw bounding boxes on the frame
    for (x, y, w, h) in boxes:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Display the resulting frame
    cv2.imshow("Live Face Detection", frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# [INFO] Loading HOG + Linear SVM face detector...
# [INFO] Starting live face detection. Press 'q' to quit.
# [INFO] Face detection took 0.1382 seconds
# [INFO] Face detection took 0.1644 seconds
# [INFO] Face detection took 0.2288 seconds
# [INFO] Face detection took 0.1891 seconds
# [INFO] Face detection took 0.1740 seconds
# [INFO] Face detection took 0.1418 seconds
# [INFO] Face detection took 0.1371 seconds
# [INFO] Face detection took 0.1479 seconds
# [INFO] Face detection took 0.1488 seconds
# [INFO] Face detection took 0.1561 seconds
# [INFO] Face detection took 0.1665 seconds
# [INFO] Face detection took 0.1836 seconds
# [INFO] Face detection took 0.1432 seconds
# [INFO] Face detection took 0.1176 seconds
# [INFO] Face detection took 0.1278 seconds
# [INFO] Face detection took 0.1205 seconds
# [INFO] Face detection took 0.1367 seconds
# [INFO] Face detection took 0.1311 seconds
# [INFO] Face detection took 0.1442 seconds
# [INFO] Face detection took 0.1431 seconds
# [INFO] Face detection took 0.1391 seconds
# [INFO] Face detection took 0.1418 seconds
# [INFO] Face detection took 0.1376 seconds
# [INFO] Face detection took 0.1305 seconds
# [INFO] Face detection took 0.1290 seconds
# [INFO] Face detection took 0.1335 seconds
# [INFO] Face detection took 0.1355 seconds
# [INFO] Face detection took 0.1368 seconds
# [INFO] Face detection took 0.1315 seconds
# [INFO] Face detection took 0.1285 seconds
# [INFO] Face detection took 0.1363 seconds
# [INFO] Face detection took 0.1419 seconds
# [INFO] Face detection took 0.1519 seconds
# [INFO] Face detection took 0.1430 seconds
# [INFO] Face detection took 0.1436 seconds
# [INFO] Face detection took 0.1268 seconds
# [INFO] Face detection took 0.1234 seconds
# [INFO] Face detection took 0.1208 seconds
# [INFO] Face detection took 0.1289 seconds
# [INFO] Face detection took 0.1257 seconds
# [INFO] Face detection took 0.1490 seconds
# [INFO] Face detection took 0.1160 seconds
# [INFO] Face detection took 0.1217 seconds
# [INFO] Face detection took 0.1221 seconds
# [INFO] Face detection took 0.1218 seconds
# [INFO] Face detection took 0.1238 seconds
# [INFO] Face detection took 0.1228 seconds
# [INFO] Face detection took 0.1263 seconds
# [INFO] Face detection took 0.1300 seconds
# [INFO] Face detection took 0.1209 seconds
# [INFO] Face detection took 0.1233 seconds
# [INFO] Face detection took 0.1224 seconds
# [INFO] Face detection took 0.1229 seconds
# [INFO] Face detection took 0.1280 seconds
# [INFO] Face detection took 0.1215 seconds
