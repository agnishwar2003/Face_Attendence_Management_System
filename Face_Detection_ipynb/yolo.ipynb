# %%
import cvzone
from ultralytics import YOLO
import cv2

# %%
import ultralytics

# %%
# Access the default laptop camera
cap = cv2.VideoCapture(0)  # 0 is the default camera index

# Load the YOLO model pretrained for face detection
facemodel = YOLO(r"D:\PythonProject\Face_Recognition_DL\model\yolov8n-face.pt")  # Ensure you have the YOLOv8 face model file

# Loop to continuously read frames from the camera
while cap.isOpened():
    ret, frame = cap.read()  # Capture a frame from the camera
    if not ret:
        print("Failed to capture frame. Exiting...")
        break

    # Resize the frame for consistent processing (optional)
    frame = cv2.resize(frame, (700, 500))

    # Perform face detection
    face_results = facemodel.predict(frame, conf=0.40)  # Confidence threshold

    # Process the detection results
    for result in face_results:
        boxes = result.boxes
        for box in boxes:
            # Get bounding box coordinates
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            w, h = x2 - x1, y2 - y1

            # Draw a fancy rectangle around the detected face
            cvzone.cornerRect(frame, [x1, y1, w, h], l=9, rt=3)

    # Display the frame with detected faces
    cv2.imshow('Face Detection - YOLOv8', frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close the window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 face, 82.7ms
# Speed: 3.0ms preprocess, 82.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 92.6ms
# Speed: 4.0ms preprocess, 92.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 72.6ms
# Speed: 3.0ms preprocess, 72.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 71.8ms
# Speed: 3.4ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 68.9ms
# Speed: 2.4ms preprocess, 68.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 77.9ms
# Speed: 2.0ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 67.1ms
# Speed: 3.4ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 72.8ms
# Speed: 4.5ms preprocess, 72.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 68.6ms
# Speed: 3.1ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 68.2ms
# Speed: 3.0ms preprocess, 68.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 64.9ms
# Speed: 2.0ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 63.5ms
# Speed: 3.2ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 60.0ms
# Speed: 4.4ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 61.9ms
# Speed: 3.1ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 61.7ms
# Speed: 3.4ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 60.3ms
# Speed: 3.0ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 63.2ms
# Speed: 3.4ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 68.4ms
# Speed: 2.0ms preprocess, 68.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 60.7ms
# Speed: 3.0ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 58.7ms
# Speed: 3.0ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 58.9ms
# Speed: 3.3ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 62.9ms
# Speed: 2.5ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 62.0ms
# Speed: 2.1ms preprocess, 62.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 63.2ms
# Speed: 3.0ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 61.6ms
# Speed: 3.5ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
import cv2
import cvzone
from ultralytics import YOLO

# Load the YOLO model pretrained for face detection
facemodel = YOLO(r"D:\PythonProject\Face_Recognition_DL\model\yolov8n-face.pt")  # Ensure you have the YOLOv8 face model file

# Load the image
image_path = r"D:\PythonProject\Face_Recognition_DL\Multiple_selfie.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Resize the image for consistent processing
image = cv2.resize(image, (600, 500))

# Perform face detection
face_results = facemodel.predict(image, conf=0.40)  # Confidence threshold

# Process the detection results
for result in face_results:
    boxes = result.boxes
    for box in boxes:
        # Get bounding box coordinates
        x1, y1, x2, y2 = box.xyxy[0]
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
        w, h = x2 - x1, y2 - y1

        # Draw a fancy rectangle around the detected face
        cvzone.cornerRect(image, [x1, y1, w, h], l=9, rt=3)

# Display the image with detected faces
cv2.imshow('Face Detection - YOLOv8', image)
cv2.imwrite(r"D:\PythonProject\Face_Recognition_DL\Face_detection_test_op\YOLO.jpg", image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 544x640 8 faces, 77.6ms
# Speed: 11.0ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
